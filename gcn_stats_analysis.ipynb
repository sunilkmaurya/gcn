# %%
import numpy as np
import pickle
import networkx as nx
from stats_calc import *

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def run_analysis(dataset_name):
    simple_classify_f1(dataset_name)
    modified_classify_f1(dataset_name)
    classify_analysis(dataset_name)

# %%
run_analysis('citeseer')
# Out:
# Name:
# Type: Graph
# Number of nodes: 3327
# Number of edges: 4676
# Average degree:   2.8109
# Simple classification results
# Train ratio: Default with planetoid
# micro: 0.721
# macro: 0.6904396008996966
# samples: 0.721
# weighted: 0.717720256831843
# Accuracy: 0.721
#
# Propagating neighbor labels for degree 1 nodes.
# Name:
# Type: Graph
# Number of nodes: 3327
# Number of edges: 4676
# Average degree:   2.8109
# Simple classification results
# Train ratio: Default with planetoid
# micro: 0.739
# macro: 0.7093517316627492
# samples: 0.739
# weighted: 0.7365210615351211
# Accuracy: 0.739
#
# +------------+-----------+---------------+-----------------+--------+----------------+----------------+
# | Serial No. |  Node no. |   True Label  | Predicted Label | Degree | Neighbor label | Neighbor Match |
# +------------+-----------+---------------+-----------------+--------+----------------+----------------+
# |     1      |  2317 436 | (array([1]),) |  (array([0]),)  |   1    | (array([2]),)  |     False      |
# |     2      |  2376 625 | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# |     3      | 2386 2385 | (array([3]),) |  (array([1]),)  |   1    | (array([3]),)  |      True      |
# |     4      | 2394 2395 | (array([3]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     5      |  2409 164 | (array([3]),) |  (array([0]),)  |   1    | (array([3]),)  |      True      |
# |     6      | 2432 1547 | (array([1]),) |  (array([5]),)  |   1    | (array([1]),)  |      True      |
# |     7      | 2459 2458 | (array([1]),) |  (array([5]),)  |   1    | (array([3]),)  |     False      |
# |     8      | 2461 2458 | (array([1]),) |  (array([5]),)  |   1    | (array([3]),)  |     False      |
# |     9      |  2471 891 | (array([3]),) |  (array([1]),)  |   1    | (array([3]),)  |      True      |
# |     10     | 2491 2492 | (array([0]),) |  (array([5]),)  |   1    | (array([5]),)  |     False      |
# |     11     | 2493 1903 | (array([1]),) |  (array([5]),)  |   1    | (array([5]),)  |     False      |
# |     12     | 2503 1069 | (array([0]),) |  (array([5]),)  |   1    | (array([0]),)  |      True      |
# |     13     | 2504 1069 | (array([1]),) |  (array([5]),)  |   1    | (array([0]),)  |     False      |
# |     14     | 2518 2044 | (array([2]),) |  (array([1]),)  |   1    | (array([0]),)  |     False      |
# |     15     |  2521 15  | (array([2]),) |  (array([3]),)  |   1    | (array([3]),)  |     False      |
# |     16     | 2526 1798 | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     17     | 2535 1944 | (array([3]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     18     |  2556 586 | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     19     | 2566 2195 | (array([5]),) |  (array([1]),)  |   1    | (array([5]),)  |      True      |
# |     20     | 2582 1862 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     21     |  2590 935 | (array([3]),) |  (array([2]),)  |   1    | (array([3]),)  |      True      |
# |     22     |  2591 821 | (array([1]),) |  (array([5]),)  |   1    | (array([1]),)  |      True      |
# |     23     | 2607 1311 | (array([5]),) |  (array([2]),)  |   1    | (array([4]),)  |     False      |
# |     24     |  2620 854 | (array([0]),) |  (array([4]),)  |   1    | (array([4]),)  |     False      |
# |     25     | 2685 2686 | (array([3]),) |  (array([5]),)  |   1    | (array([5]),)  |     False      |
# |     26     | 2688 2689 | (array([3]),) |  (array([4]),)  |   1    | (array([4]),)  |     False      |
# |     27     | 2690 2691 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     28     | 2700 1601 | (array([3]),) |  (array([0]),)  |   1    | (array([3]),)  |      True      |
# |     29     | 2741 2739 | (array([3]),) |  (array([4]),)  |   1    | (array([4]),)  |     False      |
# |     30     | 2743 2744 | (array([3]),) |  (array([5]),)  |   1    | (array([2]),)  |     False      |
# |     31     | 2744 2743 | (array([2]),) |  (array([5]),)  |   1    | (array([3]),)  |     False      |
# |     32     |  2753 639 | (array([0]),) |  (array([5]),)  |   1    | (array([0]),)  |      True      |
# |     33     | 2754 1159 | (array([5]),) |  (array([3]),)  |   1    | (array([5]),)  |      True      |
# |     34     | 2755 1159 | (array([5]),) |  (array([3]),)  |   1    | (array([5]),)  |      True      |
# |     35     | 2756 1391 | (array([0]),) |  (array([5]),)  |   1    | (array([0]),)  |      True      |
# |     36     | 2757 1106 | (array([3]),) |  (array([1]),)  |   1    | (array([3]),)  |      True      |
# |     37     | 2758 1339 | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |     38     | 2764 2765 | (array([2]),) |  (array([5]),)  |   1    | (array([2]),)  |      True      |
# |     39     | 2766 1568 | (array([3]),) |  (array([5]),)  |   1    | (array([5]),)  |     False      |
# |     40     |  2768 886 | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     41     |  2769 886 | (array([5]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     42     | 2777 1332 | (array([3]),) |  (array([5]),)  |   1    | (array([4]),)  |     False      |
# |     43     |  2792 695 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     44     | 2796 1173 | (array([3]),) |  (array([0]),)  |   1    | (array([3]),)  |      True      |
# |     45     | 2800 1979 | (array([1]),) |  (array([4]),)  |   1    | (array([1]),)  |      True      |
# |     46     | 2807 2806 | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     47     |  2808 387 | (array([5]),) |  (array([2]),)  |   1    | (array([5]),)  |      True      |
# |     48     |  2809 514 | (array([4]),) |  (array([0]),)  |   1    | (array([1]),)  |     False      |
# |     49     |  2810 514 | (array([4]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     50     | 2833 2832 | (array([0]),) |  (array([5]),)  |   1    | (array([4]),)  |     False      |
# |     51     |  2834 507 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     52     |  2838 29  | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     53     | 2847 1800 | (array([2]),) |  (array([3]),)  |   1    | (array([2]),)  |      True      |
# |     54     | 2851 2852 | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |     55     | 2852 2851 | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |     56     | 2856 1626 | (array([1]),) |  (array([4]),)  |   1    | (array([1]),)  |      True      |
# |     57     | 2864 2863 | (array([0]),) |  (array([5]),)  |   1    | (array([0]),)  |      True      |
# |     58     | 2871 1104 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     59     | 2885 1815 | (array([5]),) |  (array([0]),)  |   1    | (array([5]),)  |      True      |
# |     60     | 2892 2117 | (array([1]),) |  (array([5]),)  |   1    | (array([1]),)  |      True      |
# |     61     | 2903 2899 | (array([1]),) |  (array([4]),)  |   1    | (array([4]),)  |     False      |
# |     62     | 2915 2914 | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     63     | 2916 2917 | (array([3]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     64     |  2930 308 | (array([0]),) |  (array([5]),)  |   1    | (array([5]),)  |     False      |
# |     65     | 2934 2935 | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     66     | 2935 2934 | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     67     | 2944 1244 | (array([1]),) |  (array([5]),)  |   1    | (array([5]),)  |     False      |
# |     68     |  2961 685 | (array([2]),) |  (array([3]),)  |   1    | (array([5]),)  |     False      |
# |     69     | 2972 1458 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     70     |  2987 730 | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     71     |  2992 60  | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     72     |  2995 391 | (array([4]),) |  (array([5]),)  |   1    | (array([4]),)  |      True      |
# |     73     | 2996 2997 | (array([3]),) |  (array([1]),)  |   1    | (array([3]),)  |      True      |
# |     74     | 2997 2996 | (array([3]),) |  (array([1]),)  |   1    | (array([3]),)  |      True      |
# |     75     | 2998 1941 | (array([1]),) |  (array([3]),)  |   1    | (array([1]),)  |      True      |
# |     76     | 3000 2828 | (array([3]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     77     |  3002 336 | (array([3]),) |  (array([0]),)  |   1    | (array([3]),)  |      True      |
# |     78     | 3020 1981 | (array([3]),) |  (array([4]),)  |   1    | (array([3]),)  |      True      |
# |     79     | 3024 2635 | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     80     | 3043 1389 | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     81     | 3054 2626 | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     82     |  3055 474 | (array([5]),) |  (array([0]),)  |   1    | (array([5]),)  |      True      |
# |     83     |  3061 295 | (array([2]),) |  (array([4]),)  |   1    | (array([2]),)  |      True      |
# |     84     | 3065 1433 | (array([4]),) |  (array([5]),)  |   1    | (array([5]),)  |     False      |
# |     85     | 3074 2435 | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     86     | 3081 3080 | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     87     |  3085 326 | (array([0]),) |  (array([3]),)  |   1    | (array([0]),)  |      True      |
# |     88     | 3089 2400 | (array([5]),) |  (array([1]),)  |   1    | (array([5]),)  |      True      |
# |     89     | 3091 3090 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     90     | 3092 1664 | (array([3]),) |  (array([0]),)  |   1    | (array([3]),)  |      True      |
# |     91     | 3100 1541 | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     92     |  3130 47  | (array([0]),) |  (array([4]),)  |   1    | (array([4]),)  |     False      |
# |     93     |  3137 121 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     94     | 3143 2004 | (array([1]),) |  (array([5]),)  |   1    | (array([1]),)  |      True      |
# |     95     | 3157 1026 | (array([4]),) |  (array([3]),)  |   1    | (array([4]),)  |      True      |
# |     96     |  3158 963 | (array([3]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     97     | 3159 3019 | (array([4]),) |  (array([5]),)  |   1    | (array([4]),)  |      True      |
# |     98     | 3175 2905 | (array([2]),) |  (array([3]),)  |   1    | (array([3]),)  |     False      |
# |     99     | 3179 3178 | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    100     |  3191 596 | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# |    101     | 3198 1811 | (array([2]),) |  (array([5]),)  |   1    | (array([2]),)  |      True      |
# |    102     | 3209 1655 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    103     |  3233 935 | (array([3]),) |  (array([2]),)  |   1    | (array([3]),)  |      True      |
# |    104     |  3234 269 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |    105     |  3235 269 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |    106     |  3239 866 | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# |    107     | 3243 2056 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |    108     | 3247 1846 | (array([3]),) |  (array([2]),)  |   1    | (array([0]),)  |     False      |
# |    109     | 3255 2660 | (array([3]),) |  (array([2]),)  |   1    | (array([3]),)  |      True      |
# |    110     |  3262 788 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    111     | 3264 1475 | (array([5]),) |  (array([0]),)  |   1    | (array([4]),)  |     False      |
# |    112     | 3290 2214 | (array([2]),) |  (array([4]),)  |   1    | (array([4]),)  |     False      |
# |    113     | 3297 1664 | (array([3]),) |  (array([0]),)  |   1    | (array([3]),)  |      True      |
# |    114     |  3298 266 | (array([5]),) |  (array([0]),)  |   1    | (array([5]),)  |      True      |
# |    115     | 3300 2599 | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    116     | 3322 3323 | (array([3]),) |  (array([2]),)  |   1    | (array([3]),)  |      True      |
# |    117     | 3323 3322 | (array([3]),) |  (array([2]),)  |   1    | (array([3]),)  |      True      |
# +------------+-----------+---------------+-----------------+--------+----------------+----------------+
# Total cases of neighbor label matches are: 63
# For test set label classification prediction results
# Statistics for dataset: citeseer
# ---------------------------------
# For degree 1 total: 361 (36%) and wrong prediction: 117(32%)
# For degree 2 total: 250 (25%) and wrong prediction: 68(27%)
# For degree 3 total: 144 (14%) and wrong prediction: 43(29%)
# For degree 4 total: 87 (8%) and wrong prediction: 17(19%)
# For degree 5 total: 46 (4%) and wrong prediction: 7(15%)
# For degree 6 total: 39 (3%) and wrong prediction: 10(25%)
# For degree 7 total: 20 (2%) and wrong prediction: 8(40%)
# For degree 9 total: 9 (0%) and wrong prediction: 4(44%)
# For degree 10 total: 10 (1%) and wrong prediction: 2(20%)
# For degree 11 total: 5 (0%) and wrong prediction: 2(40%)
# For degree 12 total: 8 (0%) and wrong prediction: 1(12%)

# %%
run_analysis('pubmed')
# Out:
# Name:
# Type: Graph
# Number of nodes: 19717
# Number of edges: 44327
# Average degree:   4.4963
# Simple classification results
# Train ratio: Default with planetoid
# micro: 0.795
# macro: 0.790595109757461
# samples: 0.795
# weighted: 0.7952378079449312
# Accuracy: 0.795
#
# Propagating neighbor labels for degree 1 nodes.
# Name:
# Type: Graph
# Number of nodes: 19717
# Number of edges: 44327
# Average degree:   4.4963
# Simple classification results
# Train ratio: Default with planetoid
# micro: 0.779
# macro: 0.7677375924309894
# samples: 0.779
# weighted: 0.7794741392019301
# Accuracy: 0.779
#
# +------------+-------------+---------------+-----------------+--------+----------------+----------------+
# | Serial No. |   Node no.  |   True Label  | Predicted Label | Degree | Neighbor label | Neighbor Match |
# +------------+-------------+---------------+-----------------+--------+----------------+----------------+
# |     1      | 18764 13976 | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     2      |  18795 9737 | (array([0]),) |  (array([1]),)  |   1    | (array([2]),)  |     False      |
# |     3      | 18796 17384 | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     4      |  18855 1544 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     5      | 18885 16383 | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     6      |  18886 9830 | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     7      | 18917 13083 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     8      |  18925 3571 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     9      | 18930 15231 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     10     | 18965 15024 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     11     | 18997 17295 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     12     |  19000 3218 | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     13     |  19015 2134 | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     14     |  19030 1456 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     15     | 19047 18351 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     16     | 19085 10181 | (array([2]),) |  (array([0]),)  |   1    | (array([1]),)  |     False      |
# |     17     | 19123 10516 | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     18     | 19132 16457 | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     19     | 19136 13971 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     20     |  19139 1972 | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     21     |  19156 5048 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     22     | 19175 15970 | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     23     |  19192 8193 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     24     |  19195 5524 | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     25     | 19196 15479 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     26     |   19211 16  | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     27     |  19212 3517 | (array([2]),) |  (array([0]),)  |   1    | (array([1]),)  |     False      |
# |     28     |  19261 3410 | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     29     |  19274 8871 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     30     | 19283 14923 | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     31     |  19284 5081 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     32     | 19290 16947 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     33     |  19295 649  | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     34     |  19307 1742 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     35     | 19310 18770 | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     36     |  19315 8727 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     37     |  19318 101  | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     38     |  19319 9231 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     39     | 19362 17771 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     40     |  19375 1972 | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     41     | 19378 12483 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     42     | 19381 14640 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     43     | 19390 13755 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     44     | 19407 18035 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     45     | 19416 17048 | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     46     |  19417 8028 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     47     | 19418 12003 | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     48     | 19425 12369 | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     49     | 19427 18048 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     50     | 19434 13846 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     51     | 19440 18009 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     52     | 19448 12098 | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     53     | 19449 13361 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     54     |  19463 5730 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     55     |  19465 7087 | (array([2]),) |  (array([0]),)  |   1    | (array([1]),)  |     False      |
# |     56     |  19469 9466 | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |     57     | 19472 15813 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     58     |  19473 7057 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     59     | 19481 12253 | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     60     |  19487 9814 | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     61     |  19489 3577 | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     62     | 19490 18035 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     63     | 19505 10568 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     64     |  19506 4998 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     65     |  19509 2794 | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     66     | 19515 14893 | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     67     | 19518 14832 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     68     | 19522 18225 | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     69     |  19524 8073 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     70     |  19534 7838 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     71     | 19539 14893 | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     72     |  19555 5899 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     73     | 19559 19076 | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     74     |  19562 8028 | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     75     |  19565 9993 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     76     | 19578 11762 | (array([1]),) |  (array([0]),)  |   1    | (array([2]),)  |     False      |
# |     77     |  19582 5497 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     78     |  19584 307  | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     79     | 19595 17926 | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     80     |  19601 1433 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     81     |  19604 7716 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     82     |  19607 7533 | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     83     | 19612 10594 | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     84     | 19624 18729 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     85     | 19632 12019 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     86     |  19634 5521 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     87     |  19636 3800 | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |     88     | 19645 17441 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     89     | 19646 17689 | (array([2]),) |  (array([1]),)  |   1    | (array([0]),)  |     False      |
# |     90     |  19655 2539 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     91     | 19660 18837 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     92     | 19664 18846 | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     93     |  19665 9216 | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     94     | 19666 14376 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     95     | 19671 14815 | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     96     | 19672 18680 | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     97     | 19675 14484 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     98     | 19685 10568 | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     99     | 19694 15813 | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |    100     |  19701 9328 | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    101     |  19707 7716 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# +------------+-------------+---------------+-----------------+--------+----------------+----------------+
# Total cases of neighbor label matches are: 47
# For test set label classification prediction results
# Statistics for dataset: pubmed
# ---------------------------------
# For degree 1 total: 478 (47%) and wrong prediction: 101(21%)
# For degree 2 total: 161 (16%) and wrong prediction: 30(18%)
# For degree 3 total: 86 (8%) and wrong prediction: 21(24%)
# For degree 4 total: 36 (3%) and wrong prediction: 9(25%)
# For degree 5 total: 29 (2%) and wrong prediction: 2(6%)
# For degree 6 total: 23 (2%) and wrong prediction: 3(13%)
# For degree 7 total: 14 (1%) and wrong prediction: 6(42%)
# For degree 8 total: 14 (1%) and wrong prediction: 6(42%)
# For degree 9 total: 16 (1%) and wrong prediction: 3(18%)
# For degree 10 total: 7 (0%) and wrong prediction: 3(42%)
# For degree 11 total: 14 (1%) and wrong prediction: 2(14%)
# For degree 12 total: 8 (0%) and wrong prediction: 4(50%)
# For degree 13 total: 11 (1%) and wrong prediction: 1(9%)
# For degree 14 total: 11 (1%) and wrong prediction: 3(27%)
# For degree 15 total: 7 (0%) and wrong prediction: 2(28%)
# For degree 17 total: 10 (1%) and wrong prediction: 1(10%)
# For degree 18 total: 9 (0%) and wrong prediction: 3(33%)
# For degree 19 total: 8 (0%) and wrong prediction: 2(25%)
# For degree 20 total: 7 (0%) and wrong prediction: 1(14%)
# For degree 21 total: 3 (0%) and wrong prediction: 1(33%)
# For degree 26 total: 3 (0%) and wrong prediction: 1(33%)

# %%
run_analysis('cora')
# Out:
# Name:
# Type: Graph
# Number of nodes: 2708
# Number of edges: 5278
# Average degree:   3.8981
# Simple classification results
# Train ratio: Default with planetoid
# micro: 0.8140000000000001
# macro: 0.8037559866587299
# samples: 0.814
# weighted: 0.8117551660050972
# Accuracy: 0.814
#
# Propagating neighbor labels for degree 1 nodes.
# Name:
# Type: Graph
# Number of nodes: 2708
# Number of edges: 5278
# Average degree:   3.8981
# Simple classification results
# Train ratio: Default with planetoid
# micro: 0.8289999999999998
# macro: 0.8183500769856557
# samples: 0.829
# weighted: 0.826661532886416
# Accuracy: 0.829
#
# +------------+-----------+---------------+-----------------+--------+----------------+----------------+
# | Serial No. |  Node no. |   True Label  | Predicted Label | Degree | Neighbor label | Neighbor Match |
# +------------+-----------+---------------+-----------------+--------+----------------+----------------+
# |     1      | 1774 1623 | (array([4]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     2      |  1793 798 | (array([4]),) |  (array([5]),)  |   1    | (array([4]),)  |      True      |
# |     3      | 1854 1701 | (array([1]),) |  (array([3]),)  |   1    | (array([3]),)  |     False      |
# |     4      | 1938 1937 | (array([3]),) |  (array([0]),)  |   1    | (array([3]),)  |      True      |
# |     5      | 1990 1986 | (array([2]),) |  (array([3]),)  |   1    | (array([3]),)  |     False      |
# |     6      | 2028 2025 | (array([3]),) |  (array([6]),)  |   1    | (array([0]),)  |     False      |
# |     7      | 2032 1336 | (array([3]),) |  (array([4]),)  |   1    | (array([4]),)  |     False      |
# |     8      |  2111 711 | (array([5]),) |  (array([6]),)  |   1    | (array([0]),)  |     False      |
# |     9      | 2174 2173 | (array([6]),) |  (array([5]),)  |   1    | (array([6]),)  |      True      |
# |     10     |  2188 454 | (array([5]),) |  (array([0]),)  |   1    | (array([5]),)  |      True      |
# |     11     |  2255 225 | (array([1]),) |  (array([6]),)  |   1    | (array([1]),)  |      True      |
# |     12     |  2341 780 | (array([4]),) |  (array([3]),)  |   1    | (array([4]),)  |      True      |
# |     13     | 2345 1692 | (array([3]),) |  (array([4]),)  |   1    | (array([3]),)  |      True      |
# |     14     |  2354 577 | (array([4]),) |  (array([3]),)  |   1    | (array([4]),)  |      True      |
# |     15     |  2373 267 | (array([3]),) |  (array([0]),)  |   1    | (array([3]),)  |      True      |
# |     16     | 2397 2394 | (array([6]),) |  (array([0]),)  |   1    | (array([6]),)  |      True      |
# |     17     | 2433 1233 | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     18     | 2462 1442 | (array([3]),) |  (array([2]),)  |   1    | (array([3]),)  |      True      |
# |     19     | 2468 2467 | (array([6]),) |  (array([5]),)  |   1    | (array([6]),)  |      True      |
# |     20     | 2489 1608 | (array([3]),) |  (array([4]),)  |   1    | (array([3]),)  |      True      |
# |     21     | 2496 2290 | (array([4]),) |  (array([0]),)  |   1    | (array([4]),)  |      True      |
# |     22     | 2533 1201 | (array([0]),) |  (array([3]),)  |   1    | (array([3]),)  |     False      |
# |     23     |  2545 10  | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     24     | 2552 2306 | (array([3]),) |  (array([4]),)  |   1    | (array([4]),)  |     False      |
# |     25     | 2561 2560 | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     26     | 2571 1386 | (array([3]),) |  (array([2]),)  |   1    | (array([3]),)  |      True      |
# |     27     |  2584 876 | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     28     |  2600 832 | (array([3]),) |  (array([2]),)  |   1    | (array([3]),)  |      True      |
# |     29     |  2606 670 | (array([3]),) |  (array([2]),)  |   1    | (array([3]),)  |      True      |
# |     30     | 2607 1003 | (array([3]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     31     | 2611 1239 | (array([3]),) |  (array([0]),)  |   1    | (array([3]),)  |      True      |
# |     32     |  2617 166 | (array([4]),) |  (array([5]),)  |   1    | (array([4]),)  |      True      |
# |     33     | 2620 1925 | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     34     |  2639 917 | (array([0]),) |  (array([6]),)  |   1    | (array([0]),)  |      True      |
# |     35     | 2640 1519 | (array([3]),) |  (array([5]),)  |   1    | (array([4]),)  |     False      |
# |     36     | 2644 1885 | (array([5]),) |  (array([0]),)  |   1    | (array([5]),)  |      True      |
# |     37     | 2655 2654 | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     38     | 2660 1673 | (array([4]),) |  (array([0]),)  |   1    | (array([3]),)  |     False      |
# |     39     |  2669 592 | (array([3]),) |  (array([0]),)  |   1    | (array([3]),)  |      True      |
# |     40     |  2690 611 | (array([6]),) |  (array([3]),)  |   1    | (array([6]),)  |      True      |
# |     41     | 2692 1310 | (array([3]),) |  (array([6]),)  |   1    | (array([3]),)  |      True      |
# |     42     |  2704 641 | (array([3]),) |  (array([2]),)  |   1    | (array([3]),)  |      True      |
# |     43     |  2705 287 | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# +------------+-----------+---------------+-----------------+--------+----------------+----------------+
# Total cases of neighbor label matches are: 30
# For test set label classification prediction results
# Statistics for dataset: cora
# ---------------------------------
# For degree 1 total: 178 (17%) and wrong prediction: 43(24%)
# For degree 2 total: 222 (22%) and wrong prediction: 51(22%)
# For degree 3 total: 214 (21%) and wrong prediction: 34(15%)
# For degree 4 total: 134 (13%) and wrong prediction: 21(15%)
# For degree 5 total: 104 (10%) and wrong prediction: 11(10%)
# For degree 6 total: 54 (5%) and wrong prediction: 9(16%)
# For degree 7 total: 25 (2%) and wrong prediction: 7(28%)
# For degree 8 total: 23 (2%) and wrong prediction: 6(26%)
# For degree 9 total: 7 (0%) and wrong prediction: 1(14%)
# For degree 10 total: 10 (1%) and wrong prediction: 1(10%)
# For degree 11 total: 3 (0%) and wrong prediction: 1(33%)
# For degree 16 total: 3 (0%) and wrong prediction: 1(33%)
